# %% [markdown]
# # Programação Orientada a Objetos (POO) em Python
# Este notebook apresenta os conceitos fundamentais de POO, estruturados para facilitar o entendimento de classes e objetos.

# %% [markdown]
# ## 1. Classes e Objetos
# A **Classe** é o molde (blueprint), enquanto o **Objeto** é a instância real desse molde.

# %%
class Pessoa:
    # O método __init__ é o construtor
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

    def saudar(self):
        return f"Olá, meu nome é {self.nome} e tenho {self.idade} anos."

# Instanciando objetos
p1 = Pessoa("Alissa", 20)
print(p1.saudar())
# Out:
# Olá, meu nome é Alissa e tenho 20 anos.

# %% [markdown]
# ## 2. Encapsulamento
# Uso de atributos privados (prefixados com `__`) para proteger os dados.

# %%
class ContaBancaria:
    def __init__(self, saldo_inicial):
        self.__saldo = saldo_inicial # Atributo privado

    def depositar(self, valor):
        if valor > 0:
            self.__saldo += valor

    def consultar_saldo(self):
        return f"Saldo atual: R$ {self.__saldo:.2f}"

conta = ContaBancaria(1000)
conta.depositar(500)
print(conta.consultar_saldo())
# Out:
# Saldo atual: R$ 1500.00

# %% [markdown]
# ## 3. Herança
# Permite que uma classe filha herde atributos e métodos de uma classe pai.

# %%
class Funcionario(Pessoa):
    def __init__(self, nome, idade, cargo):
        super().__init__(nome, idade) # Chama o construtor da classe pai
        self.cargo = cargo

    def saudar(self):
        return f"Olá, sou {self.nome}, sou {self.cargo}."

professor = Funcionario("Alissa", 20, "Estudante")
print(professor.saudar())
# Out:
# Olá, sou Alissa, sou Estudante.

# %% [markdown]
# ## 4. Polimorfismo
# Capacidade de diferentes classes tratarem o mesmo método de formas distintas.

# %%
class Animal:
    def falar(self):
        pass

class Cachorro(Animal):
    def falar(self):
        return "Au Au!"

class Gato(Animal):
    def falar(self):
        return "Miau!"

animais = [Cachorro(), Gato()]
for animal in animais:
    print(animal.falar())
# Out:
# Au Au!
# Miau!
